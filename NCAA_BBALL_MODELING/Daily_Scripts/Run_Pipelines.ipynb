# %% [markdown]
# # NCAAB Pipelines Runner
#
# One cell to run everything, plus separate cells for each step.

# %%
from pathlib import Path
import sys

root = Path.cwd().parents[1] 
if str(root) not in sys.path:
    sys.path.append(str(root))

from NCAA_BBALL_MODELING.pipelines.engineering import run_engineering
from NCAA_BBALL_MODELING.pipelines.conferences import save_conference_assignments
from NCAA_BBALL_MODELING.pipelines.kenpom import fetch_fanmatch, save_team_ids
from NCAA_BBALL_MODELING.pipelines.modeling import run_modeling_pipeline
from NCAA_BBALL_MODELING.pipelines.modeling import run_predictions_only

# %% [markdown]
# ## Config

# %%
SEASON = 2026
TARGET_DATE = "2026-02-01"  # YYYY-MM-DD

# %% [markdown]
# ## Run All Steps

# %%
features_path = run_engineering(
    target_date=TARGET_DATE,
    season=SEASON,
    run_update=True,
    run_features=True,
)

predictions_path = run_modeling_pipeline(
    season_test=SEASON,
    features_path=features_path,
)

conferences_path = save_conference_assignments(
    output_path=f"data/conferences_{SEASON}.csv",
    to_year=SEASON,
)

team_ids_path = save_team_ids("data/team_ids.csv", year=SEASON)

features_path, predictions_path, conferences_path, team_ids_path

# %% [markdown]
# ## Engineering

# %%
run_engineering(
    target_date=TARGET_DATE,
    season=SEASON,
    run_update=True,
    run_features=True,
    #max_teams = 5
)
# Out:
# 1/50  Updating alabama
# 📍 Fetching: https://www.sports-reference.com/cbb/schools/alabama/2026-gamelogs.html
# 2/50  Updating duquesne
# 📍 Fetching: https://www.sports-reference.com/cbb/schools/duquesne/2026-gamelogs.html
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 run_engineering(
#       2     target_date=TARGET_DATE,
#       3     season=SEASON,
#       4     run_update=True,
#       5     run_features=True,
#       6     #max_teams = 5
#       7 )
#
# File ~/Projects/Basketball_Modeling/NCAA_BBALL_MODELING/pipelines/engineering.py:53, in run_engineering(target_date, season, run_update, run_features, base_dir, max_teams)
#      51     if not target_date:
#      52         raise ValueError("target_date is required when run_update=True")
# ---> 53     update_gamelogs(
#      54         target_date=target_date,
#      55         season=season,
#      56         max_teams=max_teams,
#      57     )
#      59 if run_features:
#      60     return create_features(only_season=season, base_dir=base_dir)
#
# File ~/Projects/Basketball_Modeling/NCAA_BBALL_MODELING/pipelines/engineering.py:20, in update_gamelogs(target_date, season, input_path, output_path, max_teams)
#      12 def update_gamelogs(
#      13     target_date: str,
#      14     season: int = 2026,
#    (...)     17     max_teams: Optional[int] = None,
#      18 ) -> None:
#      19     """Update gamelogs for a specific date (YYYY-MM-DD)."""
# ---> 20     utils.update_gamelogs_by_date(
#      21         target_date=target_date,
#      22         season=season,
#      23         input_path=input_path,
#      24         output_path=output_path,
#      25         max_teams=max_teams,
#      26     )
#
# File ~/Projects/Basketball_Modeling/NCAA_BBALL_MODELING/utils.py:432, in update_gamelogs_by_date(target_date, season, input_path, output_path, max_teams)
#     421 input_path = (
#     422     Path(input_path)
#     423     if input_path
#     424     else data_dir / f"NCAAB_{season}_Team_Gamelogs_now.xlsx"
#     425 )
#     426 output_path = (
#     427     Path(output_path)
#     428     if output_path
#     429     else data_dir / f"NCAAB_{season}_Team_Gamelogs_now.xlsx"
#     430 )
# --> 432 update_gamelogs_for_date(
#     433     input_path=input_path,
#     434     output_path=output_path,
#     435     target_date=target_date,
#     436     season=season,
#     437     max_teams=max_teams,
#     438 )
#
# File ~/Projects/Basketball_Modeling/NCAA_BBALL_MODELING/utils.py:395, in update_gamelogs_for_date(input_path, output_path, target_date, season, sleep_seconds, max_teams)
#     393     name = row["school_name"]
#     394     print(f"{i + 1}/{len(teams_today)}  Updating {slug}")
# --> 395     updated_rows.extend(scrape_team_gamelog(slug, season, name))
#     396     sleep(sleep_seconds)
#     398 updated_df = pd.DataFrame(updated_rows)
#
# File ~/Projects/Basketball_Modeling/NCAA_BBALL_MODELING/gamelog_scraping.py:79, in scrape_team_gamelog(team_slug, year, school_name)
#      72 url = (
#      73     "https://www.sports-reference.com/cbb/schools/"
#      74     + team_slug + "/" + str(year) + "-gamelogs.html"
#      75 )
#      77 print(f"📍 Fetching: {url}")
# ---> 79 page = fetch_page_safe(url, team_slug)
#      80 if page is None:
#      81     print(f"Skipping {team_slug} after retries")
#
# File ~/Projects/Basketball_Modeling/NCAA_BBALL_MODELING/gamelog_scraping.py:44, in fetch_page_safe(url, school)
#      42 while retry_count < max_retries and page is None:
#      43     try:
# ---> 44         page = urlopen(url).read()
#      45     except HTTPError as e:
#      46         if e.code == 429:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:287, in HTTPResponse._read_status(self)
#     283     print("reply:", repr(line))
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#     290     version, status, reason = line.split(None, 2)
#
# RemoteDisconnected: Remote end closed connection without response

# %%
print(root)
# Out:
# /Users/mavinjames/Projects/Basketball_Modeling

# %% [markdown]
# ## Modeling

# %%
run_modeling_pipeline(
    season_test=SEASON,
    features_path=root / "NCAA_BBALL_MODELING" /  "data" / str(SEASON) / f"features_{SEASON}.csv",
)
# Out:
# PosixPath('/Users/mavinjames/Projects/Basketball_Modeling/NCAA_BBALL_MODELING/data/predictions.csv')

# %%
run_predictions_only(
    season_test=2026
)
# Out:
# PosixPath('/Users/mavinjames/Projects/Basketball_Modeling/NCAA_BBALL_MODELING/data/predictions.csv')

# %%
import importlib
import NCAA_BBALL_MODELING.pipelines.kenpom as kp_mod
importlib.reload(kp_mod)

kp_mod.run_kenpom_history_update(
    match_date="2026-02-03",
    name_map_path=root / "NCAA_BBALL_MODELING/data/name_map_complete.csv",
)
# Out:
# PosixPath('/Users/mavinjames/Projects/Basketball_Modeling/NCAA_BBALL_MODELING/data/predictions.csv')
