# %%
import importlib
import NCAAB_Sports_Reference_Scraper.utils as u
importlib.reload(u)
# Out:
# <module 'NCAAB_Sports_Reference_Scraper.utils' from '/Users/mavinjames/Projects/Basketball_Modeling/NCAAB_Sports_Reference_Scraper/utils.py'>

# %%
import sys
from pathlib import Path

# project root (Basketball_Modeling)
root = Path.cwd().parents[1]  # adjust if needed
sys.path.append(str(root))

from NCAAB_Sports_Reference_Scraper.utils import create_features, update_gamelogs_by_date

# update gamelogs for a date
update_gamelogs_by_date("2026-01-29", season=2026)

# create features (same behavior as before)
create_features(2026)
# Out:
# 1/106  Updating albany-ny
# 📍 Fetching: https://www.sports-reference.com/cbb/schools/albany-ny/2026-gamelogs.html
# 2/106  Updating appalachian-state
# 📍 Fetching: https://www.sports-reference.com/cbb/schools/appalachian-state/2026-gamelogs.html
# 3/106  Updating binghamton
# 📍 Fetching: https://www.sports-reference.com/cbb/schools/binghamton/2026-gamelogs.html
# 4/106  Updating bryant
# 📍 Fetching: https://www.sports-reference.com/cbb/schools/bryant/2026-gamelogs.html
# 5/106  Updating cal-poly
# 📍 Fetching: https://www.sports-reference.com/cbb/schools/cal-poly/2026-gamelogs.html
# 6/106  Updating cal-state-bakersfield
# 📍 Fetching: https://www.sports-reference.com/cbb/schools/cal-state-bakersfield/2026-gamelogs.html
# 7/106  Updating cal-state-northridge
# 📍 Fetching: https://www.sports-reference.com/cbb/schools/cal-state-northridge/2026-gamelogs.html
# 8/106  Updating campbell
# 📍 Fetching: https://www.sports-reference.com/cbb/schools/campbell/2026-gamelogs.html
# ...

# %%
create_features()
# Out:
# Saved: /Users/mavinjames/Projects/Basketball_Modeling/NCAAB_Sports_Reference_Scraper/data/merged_dataset.csv

# %%
from NCAAB_Sports_Reference_Scraper.utils import create_features, update_gamelogs_by_date
create_features(2026)
# Out:
# Saved: /Users/mavinjames/Projects/Basketball_Modeling/NCAAB_Sports_Reference_Scraper/data/2026/features_2026.csv
