# %%
from kenpompy.utils import login
browser = login("bryanjames303@yahoo.com", "football")

# %%
import kenpompy.FanMatch as kp
import pandas as pd
pd.set_option("display.max_columns", None)
fm = kp.FanMatch(browser, "2026-01-25")
fm.fm_df.head()
# Out:
#                                           Game  \
# 0                   50 USC 73, 39 Wisconsin 71
# 1  73 South Florida 89, 93 Florida Atlantic 75
# 2               49 Washington 72, 86 Oregon 57
# 3        295 Mercyhurst 61, 359 Chicago St. 59
#
#                               Location ThrillScore Comeback Excitement  \
# 0              Madison, WI Kohl Center        65.5       12       1.85
# 1           Tampa, FL Yuengling Center        54.0        8       1.18
# 2    Seattle, WA Alaska Airlines Arena        49.8        0      -0.16
# 3  Erie, PA Mercyhurst Athletic Center        16.8        4       1.96
#
#   ThrillScoreRank  ExcitementRank  ComebackRank  \
# 0               1             NaN           NaN
# 1               2             NaN           NaN
# 2               3             NaN           NaN
# 3               4             NaN           NaN
#
#                                MVP Tournament Possessions PredictedWinner  \
# 0         Nick Boyd (29p/6r/3a/1s)        NaN          64       Wisconsin
# 1          Wes Enis (19p/4r/3a/1s)        NaN          71   South Florida
# 2   Jacob Ognacevic (12p/2r/1a/1s)        NaN          64      Washington
# 3  Bernie Blunt III (19p/3r/1a/1s)        NaN          58      Mercyhurst
#
#   PredictedScore WinProbability  PredictedPossessions  PredictedMOV  \
# 0          83-78            70%                  72.0             5
# 1          84-79            68%                  74.0             5
# 2          77-70            74%                  66.0             7
# 3          71-61            81%                  64.0            10
#
#      PredictedLoser   OT             Loser LoserRank LoserScore  \
# 0               USC  nan         Wisconsin        39         71
# 1  Florida Atlantic  nan  Florida Atlantic        93         75
# 2            Oregon  nan            Oregon        86         57
# 3       Chicago St.  nan       Chicago St.       359         59
#
#           Winner WinnerRank WinnerScore  ActualMOV
# 0            USC         50          73          2
# 1  South Florida         73          89         14
# 2     Washington         49          72         15
# 3     Mercyhurst        295          61          2
