# %%
import pandas as pd

gamelog1 = pd.read_excel("/Users/mavinjames/Desktop/Basketball_Modeling/NCAAB_Sports_Reference_Scraper/data/NCAAB_2023_Team_Gamelogs.xlsx")
gamelog2 = pd.read_excel("/Users/mavinjames/Desktop/Basketball_Modeling/NCAAB_Sports_Reference_Scraper/data/NCAAB_2023_Team_Gamelogs2.xlsx")
gamelog3 = pd.read_excel("/Users/mavinjames/Desktop/Basketball_Modeling/NCAAB_Sports_Reference_Scraper/data/NCAAB_2023_Team_Gamelogs3.xlsx")
gamelog4 = pd.read_excel("/Users/mavinjames/Desktop/Basketball_Modeling/NCAAB_Sports_Reference_Scraper/data/NCAAB_2023_Team_Gamelogs4.xlsx")

# %%
base_dir = "/Users/mavinjames/Desktop/Basketball_Modeling/NCAAB_Sports_Reference_Scraper/data"

files = [
    f"{base_dir}/NCAAB_2023_Team_Gamelogs.xlsx",
    f"{base_dir}/NCAAB_2023_Team_Gamelogs2.xlsx",
    f"{base_dir}/NCAAB_2023_Team_Gamelogs3.xlsx",
    f"{base_dir}/NCAAB_2023_Team_Gamelogs4.xlsx"
]

gamelogs = [pd.read_excel(f) for f in files]

# %%
final_df = pd.concat(gamelogs, ignore_index=True, sort=False)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11937 entries, 0 to 11936
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   school_name           11937 non-null  object
#  1   school_slug           11937 non-null  object
#  2   season                11937 non-null  int64
#  3   ranker                11937 non-null  int64
#  4   team_game_num_season  11937 non-null  int64
#  5   date                  11937 non-null  object
#  6   game_location         6474 non-null   object
#  7   opp_name_abbr         11937 non-null  object
#  8   game_type             11937 non-null  object
#  9   team_game_result      11937 non-null  object
#  10  team_game_score       11937 non-null  int64
#  11  opp_team_game_score   11937 non-null  int64
#  12  overtimes             721 non-null    object
#  13  fg                    11937 non-null  int64
#  14  fga                   11937 non-null  int64
# ...

# %%
len(gamelog1) + len(gamelog2) + len(gamelog3) + len(gamelog4)
# Out:
# 11937

# %%
final_df.to_csv("/Users/mavinjames/Desktop/Basketball_Modeling/NCAAB_Sports_Reference_Scraper/data/gamelogs_2023.csv")
